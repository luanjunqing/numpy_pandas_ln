# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# plot data
# Seris
data = pd.Series(np.random.randn(1000), index=np.arange(1000))
data = data.cumsum()
data.plot()
plt.show()

# %%
# DataFrame
data = pd.DataFrame(np.random.randn(1000, 4), index=np.arange(1000), columns=['a', 'b', 'c', 'd'])
print(data.head())
data = data.cumsum()
# Out:
#           a         b         c         d
# 0  1.076810  1.062563 -0.227378  0.014397
# 1 -0.878354  0.151369  0.511597 -1.040630
# 2  0.346015 -0.324570 -0.448277 -0.683624
# 3  1.634190  0.399303 -1.085485 -0.262009
# 4 -1.608611  0.842698  0.626534  0.439121

# %%
data.plot()
plt.show()

# %%
ax = data.plot.scatter(x='a', y='b', color='DarkBlue', label='Class1')
data.plot.scatter(x='a', y='c', color='DarkGreen', label='Class2', ax=ax)
plt.show()
